# %% [markdown]
# # Test Import
#
# This notebook tests that the utils package can be imported correctly.

# %%
import sys
import os

# Add notebooks directory to path
sys.path.insert(0, os.path.dirname(os.path.abspath('')))

from utils import hello_world

# Test the function
print(hello_world())
# Out:
# Hello, World!

# %%
import torch

print("torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("CUDA device count:", torch.cuda.device_count())
    print("Current device index:", torch.cuda.current_device())
    print("Current device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# Simple tensor on the selected device
x = torch.tensor([1.0, 2.0, 3.0], device=device)
print("Tensor device:", x.device)
# Out:
# torch version: 2.6.0
# CUDA available: True
# CUDA device count: 1
# Current device index: 0
# Current device name: NVIDIA GeForce RTX 5080
# /home/admin/miniforge3/envs/phys139/lib/python3.11/site-packages/torch/cuda/__init__.py:235: UserWarning:
# NVIDIA GeForce RTX 5080 with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_89 sm_90 compute_90.
# If you want to use the NVIDIA GeForce RTX 5080 GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(
# Tensor device: cuda:0
