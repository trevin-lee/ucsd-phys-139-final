# %%
from utils import download_tess_light_curves, download_gaia_data, download_asassn_catalog
import os

# --- TESS CONFIGURATION ---
SECTOR = 10           # which TESS sector (1–67+)
MAX_FILES = 20000     # how many light curves to fetch (set None for all)
TESS_DIR = f"/home/admin/main/ucsd-phys-139-final/data/tess_sector{SECTOR}"

# --- GAIA CONFIGURATION ---
GAIA_DIR = "/home/admin/main/ucsd-phys-139-final/data/gaia"
GAIA_FILES = 2

# --- ASASSN CONFIGURATION ---
ASASSN_DIR = "/home/admin/main/ucsd-phys-139-final/data/asassn"
ASASSN_FILENAME = "asassn_variables_x.csv"

# %%
# 1. Download TESS Data
print("=== Starting TESS Download ===")
download_tess_light_curves(SECTOR, MAX_FILES, TESS_DIR)
# Out:
# === Starting TESS Download ===
# 🔍 Searching for 2-minute cadence TESS light curves from Sector 10...
# Found 20000 observations.
# Filtered to 19999 light-curve products (LC only).
# Estimated total size: ~35.78 GB for 19999 products.
# ⬇️  Starting download to: /home/admin/main/ucsd-phys-139-final/data/tess_sector10
# INFO: Found cached file /home/admin/main/ucsd-phys-139-final/data/tess_sector10/mastDownload/TESS/tess2019085135100-s0010-0000000002454921-0140-s/tess2019085135100-s0010-0000000002454921-0140-s_lc.fits with expected size 1920960. [astroquery.query]
# INFO: Found cached file /home/admin/main/ucsd-phys-139-final/data/tess_sector10/mastDownload/TESS/tess2019085135100-s0010-0000000001653065-0140-s/tess2019085135100-s0010-0000000001653065-0140-s_lc.fits with expected size 1920960. [astroquery.query]
# ...

# %%
# 2. Download Gaia Data
print("\n=== Starting Gaia Download ===")
download_gaia_data(GAIA_DIR, GAIA_FILES)
# Out:
# === Starting Gaia Download ===
# 🔍 Accessing http://cdn.gea.esac.esa.int/Gaia/gdr3/gaia_source/...
# Found 3386 total files. Processing 2 files...
# ⬇️  Downloading GaiaSource_000000-003111.csv.gz...
# 📦 Unzipping GaiaSource_000000-003111.csv.gz...
# ⬇️  Downloading GaiaSource_003112-005263.csv.gz...
# 📦 Unzipping GaiaSource_003112-005263.csv.gz...
#
# ✅ Download complete! Files saved in '/home/admin/main/ucsd-phys-139-final/data/gaia'

# %%
# 3. Download ASASSN Data
print("\n=== Starting ASASSN Download ===")
download_asassn_catalog(ASASSN_DIR, ASASSN_FILENAME)
# Out:
# === Starting ASASSN Download ===
# 🔍 Downloading ASAS-SN Catalog from https://asas-sn.osu.edu/variables.csv...
#    Target: /home/admin/main/ucsd-phys-139-final/data/asassn/asassn_variables_x.csv
# ✅ Download complete! Saved to /home/admin/main/ucsd-phys-139-final/data/asassn/asassn_variables_x.csv
