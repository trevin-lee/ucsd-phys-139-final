# %%
from astroquery.mast import Observations
import os
from utils import download_tess_light_curves

SECTOR = 10           # which TESS sector (1–67+)
MAX_FILES = 20000     # how many light curves to fetch (set None for all)
DOWNLOAD_DIR = f"/home/admin/main/ucsd-phys-139-final/data/tess_sector{SECTOR}"

download_tess_light_curves(SECTOR, MAX_FILES, DOWNLOAD_DIR)
# Out:
# 🔍 Searching for 2-minute cadence TESS light curves from Sector 10...
# Found 20000 observations.
# Filtered to 19999 light-curve products (LC only).
# Estimated total size: ~35.78 GB for 19999 products.
# ⬇️  Starting download to: /home/admin/main/ucsd-phys-139-final/data/tess_sector10
# INFO: Found cached file /home/admin/main/ucsd-phys-139-final/data/tess_sector10/mastDownload/TESS/tess2019085135100-s0010-0000000002454921-0140-s/tess2019085135100-s0010-0000000002454921-0140-s_lc.fits with expected size 1920960. [astroquery.query]
# INFO: Found cached file /home/admin/main/ucsd-phys-139-final/data/tess_sector10/mastDownload/TESS/tess2019085135100-s0010-0000000001653065-0140-s/tess2019085135100-s0010-0000000001653065-0140-s_lc.fits with expected size 1920960. [astroquery.query]
# ...
